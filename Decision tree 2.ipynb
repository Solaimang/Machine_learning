# %%
import pandas as pd

# %%
df = pd.read_csv('forest 2.csv')

# %%
df
# Out:
#       age  income  gender m_status buys
# 0     <25    high    male   single  yes
# 1      45    high  female  married  yes
# 2      30     low  female   single  yes
# 3   30-40  medium  female   single   no
# 4     >22  medium  female   single  yes
# 5     <26     low    male  married  yes
# 6   30-35     low  female  married   no
# 7      44    high  female   single   no
# 8      41    high  female   single  yes
# 9      31    high    male   single  yes
# 10    >30     low    male   single  yes
# 11    >20  medium  female   single  yes
# 12  20-35  medium  female  married   no

# %%
x = df.iloc[:,:-1]

# %%
x
# Out:
#       age  income  gender m_status
# 0     <25    high    male   single
# 1      45    high  female  married
# 2      30     low  female   single
# 3   30-40  medium  female   single
# 4     >22  medium  female   single
# 5     <26     low    male  married
# 6   30-35     low  female  married
# 7      44    high  female   single
# 8      41    high  female   single
# 9      31    high    male   single
# 10    >30     low    male   single
# 11    >20  medium  female   single
# 12  20-35  medium  female  married

# %%
y = df.iloc[:,4]

# %%
y
# Out:
# 0     yes
# 1     yes
# 2     yes
# 3      no
# 4     yes
# 5     yes
# 6      no
# 7      no
# 8     yes
# 9     yes
# 10    yes
# 11    yes
# 12     no
# Name: buys, dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
x = x.apply(label.fit_transform)

# %%
x
# Out:
#     age  income  gender  m_status
# 0     8       0       1         1
# 1     7       0       0         0
# 2     1       1       0         1
# 3     3       2       0         1
# 4    11       2       0         1
# 5     9       1       1         0
# 6     2       1       0         0
# 7     6       0       0         1
# 8     5       0       0         1
# 9     4       0       1         1
# 10   12       1       1         1
# 11   10       2       0         1
# 12    0       2       0         0

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
import numpy as np

# %%
mod = DecisionTreeClassifier()

# %%
mod.fit(x.iloc[:,0:4],y)
# Out:
# DecisionTreeClassifier()

# %%
x_input = np.array([0,2,0,0])

# %%
prediction = mod.predict(x_input)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\SOLAIM~1\AppData\Local\Temp/ipykernel_9052/422125118.py in <module>
# ----> 1 prediction = mod.predict(x_input)
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in predict(self, X, check_input)
#     440         """
#     441         check_is_fitted(self)
# --> 442         X = self._validate_X_predict(X, check_input)
#     443         proba = self.tree_.predict(X)
#     444         n_samples = X.shape[0]
#
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     405         """Validate the training data on predict (probabilities)."""
#     406         if check_input:
# --> 407             X = self._validate_data(X, dtype=DTYPE, accept_sparse="csr",
#     408                                     reset=False)
# ...
