# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sas

# %%
df =pd.read_csv('cardio.csv')

# %%
df
# Out:
#       id  age  gender  height  weight  ap_hi  ap_io  cholesteral  glue  smoke  \
# 0      1   20       2     168    62.5    123     80            2     0      1
# 1      2   34       1     145    64.2    121     90            1     0      1
# 2      3   56       1     156    65.3    102     60            2     0      0
# 3      4   34       2     165    70.3    107     78            2     0      0
# 4      5   65       2     168    80.3    104     89            1     0      0
# ..   ...  ...     ...     ...     ...    ...    ...          ...   ...    ...
# 173  183   82       1     163    43.6    123     93            1     0      2
# 174  184   73       2     138   123.4    176     84            2     0      0
# 175  185   92       1     145    65.3    123     96            2     1      0
# 176  186   29       2     123    70.3    180     85            2     0      1
# 177  187   19       1     145    80.3    145     87            3     1      0
#
#      alco  active  cardio
# ...

# %%
df.head()
# Out:
#    id  age  gender  height  weight  ap_hi  ap_io  cholesteral  glue  smoke  \
# 0   1   20       2     168    62.5    123     80            2     0      1
# 1   2   34       1     145    64.2    121     90            1     0      1
# 2   3   56       1     156    65.3    102     60            2     0      0
# 3   4   34       2     165    70.3    107     78            2     0      0
# 4   5   65       2     168    80.3    104     89            1     0      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       0       1
# 2     0       1       1
# 3     1       0       0
# 4     1       1       1

# %%
df.isnull().sum()
# Out:
# id             0
# age            0
# gender         0
# height         0
# weight         0
# ap_hi          0
# ap_io          0
# cholesteral    0
# glue           0
# smoke          0
# alco           0
# active         0
# cardio         0
# dtype: int64

# %%
df.shape
# Out:
# (178, 13)

# %%
sas.histplot(df['weight'],kde=True)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
mean_value = df['weight'].mean()

# %%
mean_value
# Out:
# 78.34831460674151

# %%
std_value = df['weight'].std()

# %%
std_value
# Out:
# 20.361762726350396

# %%
std_3 = mean_value + (2 * std_value)

# %%
std_3
# Out:
# 119.07184005944231

# %%
std_neg_3 = mean_value - (2* std_value)

# %%
std_neg_3
# Out:
# 37.62478915404072

# %%
df[df['weight']>std_3]
# Out:
#       id  age  gender  height  weight  ap_hi  ap_io  cholesteral  glue  smoke  \
# 11    12   73       2     138   123.4    176     84            2     0      0
# 21    22   56       2     123   123.4    198     75            1     0      1
# 27    28   40       1     145   123.4    154     98            2     0      0
# 37    38   78       1     193   123.4    176     58            2     0      1
# 44    45   73       2     138   123.4    176     84            2     0      0
# 54    55   56       2     123   123.4    198     75            1     0      1
# 66    68   78       1     193   123.4    176     58            2     0      1
# 73    75   73       2     138   123.4    176     84            2     0      0
# 85    87   73       2     138   123.4    176     84            2     0      0
# 100  110   73       2     138   123.4    176     84            2     0      0
# 110  120   56       2     123   123.4    198     75            1     0      1
# ...

# %%
df[df['weight'] < std_neg_3]
# Out:
# Empty DataFrame
# Columns: [id, age, gender, height, weight, ap_hi, ap_io, cholesteral, glue, smoke, alco, active, cardio]
# Index: []

# %%
marge = df[(df['weight']>std_3) | (df['weight']<std_neg_3)]

# %%
marge
# Out:
#       id  age  gender  height  weight  ap_hi  ap_io  cholesteral  glue  smoke  \
# 11    12   73       2     138   123.4    176     84            2     0      0
# 21    22   56       2     123   123.4    198     75            1     0      1
# 27    28   40       1     145   123.4    154     98            2     0      0
# 37    38   78       1     193   123.4    176     58            2     0      1
# 44    45   73       2     138   123.4    176     84            2     0      0
# 54    55   56       2     123   123.4    198     75            1     0      1
# 66    68   78       1     193   123.4    176     58            2     0      1
# 73    75   73       2     138   123.4    176     84            2     0      0
# 85    87   73       2     138   123.4    176     84            2     0      0
# 100  110   73       2     138   123.4    176     84            2     0      0
# 110  120   56       2     123   123.4    198     75            1     0      1
# ...

# %%
outline_removing = marge = df[(df['weight']<std_3) & (df['weight']>std_neg_3)]

# %%
outline_removing
# Out:
#       id  age  gender  height  weight  ap_hi  ap_io  cholesteral  glue  smoke  \
# 0      1   20       2     168    62.5    123     80            2     0      1
# 1      2   34       1     145    64.2    121     90            1     0      1
# 2      3   56       1     156    65.3    102     60            2     0      0
# 3      4   34       2     165    70.3    107     78            2     0      0
# 4      5   65       2     168    80.3    104     89            1     0      0
# ..   ...  ...     ...     ...     ...    ...    ...          ...   ...    ...
# 172  182   34       2     162    89.3    176     82            1     2      2
# 173  183   82       1     163    43.6    123     93            1     0      2
# 175  185   92       1     145    65.3    123     96            2     1      0
# 176  186   29       2     123    70.3    180     85            2     0      1
# 177  187   19       1     145    80.3    145     87            3     1      0
#
#      alco  active  cardio
# ...

# %%
outline_removing.shape
# Out:
# (160, 13)

# %%
sas.histplot(outline_removing['weight'],kde=True)
# Out:
# <AxesSubplot:xlabel='weight', ylabel='Count'>

# %%
dummy_variable=pd.get_dummies(outline_removing['gender'],drop_first=True)

# %%
dummy_variable.head()
# Out:
#    2
# 0  1
# 1  0
# 2  0
# 3  1
# 4  1

# %%
new_df = outline_removing.drop('gender',axis=1)

# %%
new_df
# Out:
#       id  age  height  weight  ap_hi  ap_io  cholesteral  glue  smoke  alco  \
# 0      1   20     168    62.5    123     80            2     0      1     0
# 1      2   34     145    64.2    121     90            1     0      1     0
# 2      3   56     156    65.3    102     60            2     0      0     0
# 3      4   34     165    70.3    107     78            2     0      0     1
# 4      5   65     168    80.3    104     89            1     0      0     1
# ..   ...  ...     ...     ...    ...    ...          ...   ...    ...   ...
# 172  182   34     162    89.3    176     82            1     2      2     0
# 173  183   82     163    43.6    123     93            1     0      2     1
# 175  185   92     145    65.3    123     96            2     1      0     1
# 176  186   29     123    70.3    180     85            2     0      1     1
# 177  187   19     145    80.3    145     87            3     1      0     0
#
#      active  cardio
# 0         1       0
# ...

# %%
df = pd.concat([new_df,dummy_variable],axis=1)

# %%
df.head()
# Out:
#    id  age  height  weight  ap_hi  ap_io  cholesteral  glue  smoke  alco  \
# 0   1   20     168    62.5    123     80            2     0      1     0
# 1   2   34     145    64.2    121     90            1     0      1     0
# 2   3   56     156    65.3    102     60            2     0      0     0
# 3   4   34     165    70.3    107     78            2     0      0     1
# 4   5   65     168    80.3    104     89            1     0      0     1
#
#    active  cardio  2
# 0       1       0  1
# 1       0       1  0
# 2       1       1  0
# 3       0       0  1
# 4       1       1  1

# %%
x=df.drop('height',axis=1)

# %%
x.head()
# Out:
#    id  age  weight  ap_hi  ap_io  cholesteral  glue  smoke  alco  active  \
# 0   1   20    62.5    123     80            2     0      1     0       1
# 1   2   34    64.2    121     90            1     0      1     0       0
# 2   3   56    65.3    102     60            2     0      0     0       1
# 3   4   34    70.3    107     78            2     0      0     1       0
# 4   5   65    80.3    104     89            1     0      0     1       1
#
#    cardio  2
# 0       0  1
# 1       1  0
# 2       1  0
# 3       0  1
# 4       1  1

# %%
y=df['height']

# %%
y.head()
# Out:
# 0    168
# 1    145
# 2    156
# 3    165
# 4    168
# Name: height, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
xtrian,ytest,ytrain,ytest = train_test_split(x,y,test_size=.25,random_state=30)

# %%
xtrain
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SOLAIM~1\AppData\Local\Temp/ipykernel_8344/4186857385.py in <module>
# ----> 1 xtrain
#
# NameError: name 'xtrain' is not defined
